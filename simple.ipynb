# %%
import gym

from stable_baselines3 import SAC

env = gym.make("CartPole-v1")

model = SAC("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10000)

obs = env.reset()
for i in range(1000):
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, done, info = env.step(action)
    env.render()
    if done:
      obs = env.reset()

env.close()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | 21.6     |
# | time/              |          |
# |    fps             | 2164     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 27.2         |
# |    ep_rew_mean          | 27.2         |
# | time/                   |              |
# |    fps                  | 1492         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0151557885 |
# |    clip_fraction        | 0.126        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.686       |
# |    explained_variance   | -0.00261     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.08         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0203      |
# |    value_loss           | 54.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.7        |
# |    ep_rew_mean          | 35.7        |
# | time/                   |             |
# |    fps                  | 1403        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011703132 |
# |    clip_fraction        | 0.0784      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.666      |
# |    explained_variance   | 0.0639      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.5        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0197     |
# |    value_loss           | 37          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 47.4         |
# |    ep_rew_mean          | 47.4         |
# | time/                   |              |
# |    fps                  | 1372         |
# |    iterations           | 4            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0092798835 |
# |    clip_fraction        | 0.0853       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.634       |
# |    explained_variance   | 0.204        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.1         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0184      |
# |    value_loss           | 55.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61.6         |
# |    ep_rew_mean          | 61.6         |
# | time/                   |              |
# |    fps                  | 1357         |
# |    iterations           | 5            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0068053193 |
# |    clip_fraction        | 0.0786       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.613       |
# |    explained_variance   | 0.302        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.3         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0179      |
# |    value_loss           | 63.6         |
# ------------------------------------------
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/miniconda3/envs/afrl/lib/python3.7/site-packages/gym/envs/classic_control/rendering.py in <module>
#      24 try:
# ---> 25     from pyglet.gl import *
#      26 except ImportError as e:
#
# ~/miniconda3/envs/afrl/lib/python3.7/site-packages/pyglet/gl/__init__.py in <module>
#      94
# ---> 95 from pyglet.gl.lib import GLException
#      96 from pyglet.gl.gl import *
#
# ~/miniconda3/envs/afrl/lib/python3.7/site-packages/pyglet/gl/lib.py in <module>
#     146 elif pyglet.compat_platform == 'darwin':
# --> 147     from pyglet.gl.lib_agl import link_GL, link_GLU, link_AGL
#     148 else:
#
# ~/miniconda3/envs/afrl/lib/python3.7/site-packages/pyglet/gl/lib_agl.py in <module>
#      42
# ---> 43 gl_lib = pyglet.lib.load_library(framework='/System/Library/Frameworks/OpenGL.framework')
#      44 agl_lib = pyglet.lib.load_library(framework='/System/Library/Frameworks/AGL.framework')
#
# ~/miniconda3/envs/afrl/lib/python3.7/site-packages/pyglet/lib.py in load_library(self, *names, **kwargs)
#     123         if 'framework' in kwargs and self.platform == 'darwin':
# --> 124             return self.load_framework(kwargs['framework'])
#     125
#
# ~/miniconda3/envs/afrl/lib/python3.7/site-packages/pyglet/lib.py in load_framework(self, path)
#     278
# --> 279         raise ImportError("Can't find framework %s." % path)
#     280
#
# ImportError: Can't find framework /System/Library/Frameworks/OpenGL.framework.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# /var/folders/_4/97ylq00j7cv25z1v50spj_g00000gn/T/ipykernel_3205/554375967.py in <module>
#      12     action, _states = model.predict(obs, deterministic=True)
#      13     obs, reward, done, info = env.step(action)
# ---> 14     env.render()
#      15     if done:
#      16       obs = env.reset()
#
# ~/miniconda3/envs/afrl/lib/python3.7/site-packages/gym/core.py in render(self, mode, **kwargs)
#     238
#     239     def render(self, mode='human', **kwargs):
# --> 240         return self.env.render(mode, **kwargs)
#     241
#     242     def close(self):
#
# ~/miniconda3/envs/afrl/lib/python3.7/site-packages/gym/envs/classic_control/cartpole.py in render(self, mode)
#     172
#     173         if self.viewer is None:
# --> 174             from gym.envs.classic_control import rendering
#     175             self.viewer = rendering.Viewer(screen_width, screen_height)
#     176             l, r, t, b = -cartwidth / 2, cartwidth / 2, cartheight / 2, -cartheight / 2
#
# ~/miniconda3/envs/afrl/lib/python3.7/site-packages/gym/envs/classic_control/rendering.py in <module>
#      30     If you're running on a server, you may need a virtual frame buffer; something like this should work:
#      31     'xvfb-run -s \"-screen 0 1400x900x24\" python <your_script.py>'
# ---> 32     ''')
#      33
#      34 import math
#
# ImportError:
#     Error occurred while running `from pyglet.gl import *`
#     HINT: make sure you have OpenGL install. On Ubuntu, you can run 'apt-get install python-opengl'.
#     If you're running on a server, you may need a virtual frame buffer; something like this should work:
#     'xvfb-run -s "-screen 0 1400x900x24" python <your_script.py>'
